# %% [markdown]
# ##  Notebook 2 — Daily Feature Pipeline
#
# **Goal**: fetch yesterday’s electricity prices and observed weather, derive features, and upsert into Hopsworks Feature Store.
#
# ### What this pipeline writes
# - **`electricity_prices` (v3)**: hourly prices + calendar + lag features
# - **`weather_hourly` (v3)**: hourly observed weather + calendar features
#
# ### Run order
# 1. **Setup & login**
# 2. **Load feature groups (v3)**
# 3. **Config** (price area, location, dates)
# 4. **⚡ Prices**: fetch → feature engineering → insert
# 5. **🌦 Weather**: fetch → feature engineering → insert
#
# ### Notes
# - Primary key is **(`price_area`, `unix_time`)**, where `unix_time` is **epoch ms**.
# - Inserts use `storage="both"` to keep **online + offline** stores in sync (serving + training).

# %%
# --- Imports ---
from pathlib import Path
import datetime
import sys
import warnings

import holidays
import pandas as pd

import hopsworks
from dotenv import load_dotenv

warnings.filterwarnings("ignore")


# --- Project path bootstrap ---
# Add repo root to sys.path.
root_dir = Path("..").resolve()
if str(root_dir) not in sys.path:
    sys.path.append(str(root_dir))

# Project imports (after sys.path update)
from src.config import ElectricitySettings
from src import util


# --- Hopsworks login ---
# Load local env vars (used locally; GitHub Actions uses secrets).
env_path = root_dir / ".env"
load_dotenv(env_path)

settings = ElectricitySettings()
project = hopsworks.login(engine="python")
fs = project.get_feature_store()

print("Successfully logged in to Hopsworks project:", settings.HOPSWORKS_PROJECT)
# Out:
# ElectricitySettings initialized
# 2026-01-22 17:15:48,688 INFO: Closing external client and cleaning up certificates.
# 2026-01-22 17:15:48,690 INFO: Connection closed.
# 2026-01-22 17:15:48,691 INFO: Initializing external client
# 2026-01-22 17:15:48,691 INFO: Base URL: https://eu-west.cloud.hopsworks.ai:443
# 2026-01-22 17:15:49,890 INFO: Python Engine initialized.
#
# Logged in to project, explore it here https://eu-west.cloud.hopsworks.ai:443/p/127
# Successfully logged in to Hopsworks project: ScalableProject

# %%
# Get the feature groups (v3)
electricity_prices_fg = fs.get_feature_group('electricity_prices', version=3)
weather_hourly_fg = fs.get_feature_group('weather_hourly', version=3)

# %% [markdown]
# ##  Configuration
#
# Define the price area and date range for historical data collection.

# %%
# --- Configuration ---
# Location config is duplicated here on purpose: daily pipelines should be explicit.
PRICE_AREA = "SE3"
CITY = "Stockholm"
LATITUDE = 59.3251
LONGITUDE = 18.0711

# Calendar helpers
SEASON_MAP = {12: 0, 1: 0, 2: 0, 3: 1, 4: 1, 5: 1, 6: 2, 7: 2, 8: 2, 9: 3, 10: 3, 11: 3}

today = datetime.date.today()
yesterday = today - datetime.timedelta(days=1)

# %% [markdown]
# ##  Step 1 — Prices (yesterday)
# Fetch electricity prices, compute time/holiday + lag features, and upsert to `electricity_prices` (v3).

# %%
# --- Prices ---
# Daily run: build and upsert features for yesterday (local calendar day).
# Use a longer lookback so lag_72 is available even if a day has a missing hour.
lookback_days = 10
window_start = yesterday - datetime.timedelta(days=lookback_days)

raw_prices = util.fetch_electricity_prices(
    start_date=window_start,
    end_date=yesterday,
    price_area=PRICE_AREA,
    show_progress=False,
    request_pause=0,
)
raw_prices = util.align_electricity_price_schema(raw_prices)

local_tz = "Europe/Stockholm"

# Keys
_df = raw_prices.copy()
_df["date"] = pd.to_datetime(_df["timestamp"], utc=True)  # event_time stored as UTC
_df["unix_time"] = _df["date"].astype("int64") // 10**6

# Local time used for day filtering + calendar/hour features
_df["local_time"] = _df["date"].dt.tz_convert(local_tz)
_df["hour"] = _df["local_time"].dt.hour.astype("int16")

_df = _df.drop(columns=["timestamp"], errors="ignore")
_df = _df.drop(columns=["price_eur", "exchange_rate"], errors="ignore")
_df["price_area"] = PRICE_AREA.lower()
_df["price_area"] = _df["price_area"].astype("string")

_df = _df.sort_values(["price_area", "unix_time"])

# Calendar (local)
_df["weekday"] = _df["local_time"].dt.weekday.astype("int8")
_df["is_weekend"] = _df["weekday"].isin([5, 6]).astype("int8")
_df["month"] = _df["local_time"].dt.month.astype("int8")
_df["season"] = _df["month"].map(SEASON_MAP).astype("int8")

# Holidays (local)
try:
    years = range(_df["local_time"].dt.year.min(), _df["local_time"].dt.year.max() + 1)
    se_holidays = holidays.Sweden(years=years)
    _df["is_holiday"] = _df["local_time"].dt.date.isin(se_holidays).astype("int8")
except Exception:
    _df["is_holiday"] = 0

# Lags + rolling
for lag in (24, 48, 72):
    _df[f"price_lag_{lag}"] = _df.groupby("price_area")["price_sek"].shift(lag).astype("float32")

roll = (
    _df.groupby("price_area")["price_sek"]
    .rolling(72, min_periods=1)
    .mean()
    .reset_index(level=0, drop=True)
)
_df["price_roll3d"] = roll.astype("float32")

# Filter yesterday by *local* day boundaries (prevents dropping 00:00 local hour)
mask_yesterday = _df["local_time"].dt.date == yesterday

df_prices = _df.loc[mask_yesterday].copy()
# Only drop rows where the actual price is missing; lags may be NaN at boundaries.
df_prices = df_prices.dropna(subset=["price_sek"]).reset_index(drop=True)

cols_out = [
    "unix_time",
    "date",
    "hour",
    "price_area",
    "price_sek",
    "weekday",
    "is_weekend",
    "month",
    "season",
    "is_holiday",
    "price_lag_24",
    "price_lag_48",
    "price_lag_72",
    "price_roll3d",
]
df_prices = df_prices[cols_out]

print(f"Prices: inserting {len(df_prices)} row(s) for {yesterday}")
electricity_prices_fg.insert(df_prices, storage="both", wait=True)
# Out:
# Fetching electricity prices from 2025-12-21 to 2026-01-21 for SE3...
# Coerced electricity prices to hourly resolution (aggregated sub-hour data).
# Fetched 768 hourly price records across 32 day(s)
# Prices: inserting 24 row(s) for 2025-12-31
# 2026-01-22 17:15:53,050 INFO: 	2 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://eu-west.cloud.hopsworks.ai:443/p/127/fs/74/fg/2198
# Uploading Dataframe: 100.00% |██████████| Rows 24/24 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: electricity_prices_2_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://eu-west.cloud.hopsworks.ai:443/p/127/jobs/named/electricity_prices_2_offline_fg_materialization/executions
# 2026-01-22 17:16:05,295 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2026-01-22 17:16:08,681 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2026-01-22 17:18:34,068 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2026-01-22 17:18:34,149 INFO: Waiting for log aggregation to finish.
# 2026-01-22 17:18:42,859 INFO: Execution finished successfully.
# Online data ingestion progress: 0.00% |          | Rows 0/23
# Prices: inserting 24 row(s) for 2026-01-01
# 2026-01-22 17:18:43,455 INFO: 	2 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://eu-west.cloud.hopsworks.ai:443/p/127/fs/74/fg/2198
# Uploading Dataframe: 100.00% |██████████| Rows 24/24 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: electricity_prices_2_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://eu-west.cloud.hopsworks.ai:443/p/127/jobs/named/electricity_prices_2_offline_fg_materialization/executions
# 2026-01-22 17:18:55,618 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2026-01-22 17:18:58,846 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2026-01-22 17:21:28,337 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2026-01-22 17:21:28,417 INFO: Waiting for log aggregation to finish.
# 2026-01-22 17:21:37,265 INFO: Execution finished successfully.
# Online data ingestion progress: 0.00% |          | Rows 0/23
# Prices: inserting 24 row(s) for 2026-01-02
# 2026-01-22 17:21:37,825 INFO: 	2 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://eu-west.cloud.hopsworks.ai:443/p/127/fs/74/fg/2198
# Uploading Dataframe: 100.00% |██████████| Rows 24/24 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: electricity_prices_2_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://eu-west.cloud.hopsworks.ai:443/p/127/jobs/named/electricity_prices_2_offline_fg_materialization/executions
# 2026-01-22 17:21:49,698 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2026-01-22 17:21:52,930 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2026-01-22 17:24:12,575 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2026-01-22 17:24:12,648 INFO: Waiting for log aggregation to finish.
# 2026-01-22 17:24:21,153 INFO: Execution finished successfully.
# Online data ingestion progress: 0.00% |          | Rows 0/24
# Prices: inserting 24 row(s) for 2026-01-03
# 2026-01-22 17:24:21,762 INFO: 	2 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://eu-west.cloud.hopsworks.ai:443/p/127/fs/74/fg/2198
# Uploading Dataframe: 100.00% |██████████| Rows 24/24 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: electricity_prices_2_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://eu-west.cloud.hopsworks.ai:443/p/127/jobs/named/electricity_prices_2_offline_fg_materialization/executions
# 2026-01-22 17:24:33,494 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2026-01-22 17:24:36,721 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2026-01-22 17:26:55,031 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2026-01-22 17:26:55,111 INFO: Waiting for log aggregation to finish.
# 2026-01-22 17:27:03,817 INFO: Execution finished successfully.
# Online data ingestion progress: 0.00% |          | Rows 0/24
# Prices: inserting 24 row(s) for 2026-01-04
# 2026-01-22 17:27:04,428 INFO: 	2 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://eu-west.cloud.hopsworks.ai:443/p/127/fs/74/fg/2198
# Uploading Dataframe: 100.00% |██████████| Rows 24/24 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: electricity_prices_2_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://eu-west.cloud.hopsworks.ai:443/p/127/jobs/named/electricity_prices_2_offline_fg_materialization/executions
# 2026-01-22 17:27:16,361 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2026-01-22 17:27:26,160 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2026-01-22 17:29:42,255 INFO: Waiting for execution to finish. Current state: AGGREGATING_LOGS. Final status: SUCCEEDED
# 2026-01-22 17:29:42,340 INFO: Waiting for log aggregation to finish.
# 2026-01-22 17:29:50,841 INFO: Execution finished successfully.
# Online data ingestion progress: 0.00% |          | Rows 0/24
# Prices: inserting 24 row(s) for 2026-01-05
# 2026-01-22 17:29:51,352 INFO: 	2 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://eu-west.cloud.hopsworks.ai:443/p/127/fs/74/fg/2198
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 97
#      95 df_prices = df_prices[cols_out]
#      96 print(f"Prices: inserting {len(df_prices)} row(s) for {cur}")
# ---> 97 electricity_prices_fg.insert(df_prices, storage="both", wait=True)
#      99 cur = cur + datetime.timedelta(days=1)
#
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hsfs/feature_group.py:3454, in FeatureGroup.insert(self, features, overwrite, operation, storage, write_options, validation_options, wait, transformation_context, transform)
#    3444 if all(
#    3445     [
#    3446         not self._id,
#    (...)   3450 ):
#    3451     # New delta FG allow for change data capture query
#    3452     write_options["delta.enableChangeDataFeed"] = "true"
# -> 3454 job, ge_report = self._feature_group_engine.insert(
#    3455     self,
#    3456     feature_dataframe=feature_dataframe,
#    3457     overwrite=overwrite,
#    3458     operation=operation,
#    3459     storage=storage.lower() if storage is not None else None,
#    3460     write_options=write_options,
#    3461     validation_options={"save_report": True, **validation_options},
#    3462     transformation_context=transformation_context,
#    3463     transform=transform,
#    3464 )
#    3466 # Compute stats in client if there is no backfill job:
#    3467 # - spark engine: always compute in client
#    3468 # - python engine: only compute if FG is offline only (no backfill job)
#    3469 if engine.get_type().startswith("spark") and not self.stream:
#
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hsfs/core/feature_group_engine.py:247, in FeatureGroupEngine.insert(self, feature_group, feature_dataframe, overwrite, operation, storage, write_options, validation_options, transformation_context, transform)
#     243 if overwrite:
#     244     self._feature_group_api.delete_content(feature_group)
#     246 return (
# --> 247     engine.get_instance().save_dataframe(
#     248         feature_group,
#     249         feature_dataframe,
#     250         "bulk_insert" if overwrite else operation,
#     251         feature_group.online_enabled,
#     252         storage,
#     253         offline_write_options,
#     254         online_write_options,
#     255     ),
#     256     ge_report,
#     257 )
#
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hsfs/engine/python.py:1079, in Engine.save_dataframe(self, feature_group, dataframe, operation, online_enabled, storage, offline_write_options, online_write_options, validation_id)
#    1073     _logger.debug("No duplicate records found. Proceeding with Delta write.")
#    1075 if (
#    1076     hasattr(feature_group, "EXTERNAL_FEATURE_GROUP")
#    1077     and feature_group.online_enabled
#    1078 ) or feature_group.stream:
# -> 1079     return self._write_dataframe_kafka(
#    1080         feature_group, dataframe, offline_write_options
#    1081     )
#    1082 elif engine.get_type() == "python":
#    1083     if feature_group.time_travel_format == "DELTA":
#
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hsfs/engine/python.py:1790, in Engine._write_dataframe_kafka(self, feature_group, dataframe, offline_write_options)
#    1782 producer, headers, feature_writers, writer = kafka_engine.init_kafka_resources(
#    1783     feature_group,
#    1784     offline_write_options,
#    1785     num_entries=len(dataframe),
#    1786 )
#    1788 if not feature_group._multi_part_insert:
#    1789     # set initial_check_point to the current offset
# -> 1790     initial_check_point = kafka_engine.kafka_get_offsets(
#    1791         topic_name=feature_group._online_topic_name,
#    1792         feature_store_id=feature_group.feature_store_id,
#    1793         offline_write_options=offline_write_options,
#    1794         high=True,
#    1795     )
#    1797 acked, progress_bar = kafka_engine.build_ack_callback_and_optional_progress_bar(
#    1798     n_rows=dataframe.shape[0],
#    1799     is_multi_part_insert=feature_group._multi_part_insert,
#    1800     offline_write_options=offline_write_options,
#    1801 )
#    1803 if isinstance(dataframe, pd.DataFrame):
#
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hopsworks_common/decorators.py:139, in uses_confluent_kafka.<locals>.g(*args, **kwds)
#     137 if not HAS_CONFLUENT_KAFKA:
#     138     raise ModuleNotFoundError(confluent_kafka_not_installed_message)
# --> 139 return f(*args, **kwds)
#
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hsfs/core/kafka_engine.py:180, in kafka_get_offsets(topic_name, feature_store_id, offline_write_options, high)
#     176 for partition_metadata in topics.get(topic_name).partitions.values():
#     177     partition = TopicPartition(
#     178         topic=topic_name, partition=partition_metadata.id
#     179     )
# --> 180     offsets += f",{partition_metadata.id}:{consumer.get_watermark_offsets(partition)[tuple_value]}"
#     181 consumer.close()
#     183 return f"{topic_name + offsets}"
#
# KeyboardInterrupt:
# %6|1769099443.181|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50052ms in state UP)
# %6|1769099443.204|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50213ms in state UP)
# %6|1769099443.275|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50342ms in state UP)
# %6|1769099443.560|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50034ms in state UP)
# %6|1769099493.255|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 100373ms in state UP)
# %6|1769099493.329|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50036ms in state UP, 1 identical error(s) suppressed)
# %6|1769099493.764|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50037ms in state UP)
# %6|1769099543.534|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50083ms in state UP, 1 identical error(s) suppressed)
# %6|1769099543.634|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769099543.689|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769099543.957|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50037ms in state UP)
# %6|1769099593.573|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 99863ms in state UP, 1 identical error(s) suppressed)
# %6|1769099593.704|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50040ms in state UP, 1 identical error(s) suppressed)
# %6|1769099594.183|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50043ms in state UP, 1 identical error(s) suppressed)
# %6|1769099643.863|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50040ms in state UP, 1 identical error(s) suppressed)
# %6|1769099644.031|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769099644.088|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769099644.347|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50041ms in state UP, 1 identical error(s) suppressed)
# %6|1769099694.010|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50025ms in state UP, 1 identical error(s) suppressed)
# %6|1769099742.441|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 97958ms in state UP, 1 identical error(s) suppressed)
# %6|1769099744.037|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 149936ms in state UP, 1 identical error(s) suppressed)
# %6|1769099744.158|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50029ms in state UP, 1 identical error(s) suppressed)
# %6|1769099792.898|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50036ms in state UP, 1 identical error(s) suppressed)
# %6|1769099794.279|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50001ms in state UP, 1 identical error(s) suppressed)
# %6|1769099843.084|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769099844.319|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 99272ms in state UP, 1 identical error(s) suppressed)
# %6|1769099844.439|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50040ms in state UP, 1 identical error(s) suppressed)
# %6|1769099893.265|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769099894.650|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50077ms in state UP, 1 identical error(s) suppressed)
# %6|1769099894.650|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50078ms in state UP, 1 identical error(s) suppressed)
# %6|1769099943.467|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50052ms in state UP, 1 identical error(s) suppressed)
# %6|1769099944.799|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769099944.828|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50043ms in state UP, 1 identical error(s) suppressed)
# %6|1769099994.964|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50040ms in state UP, 1 identical error(s) suppressed)
# %6|1769100042.454|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 98854ms in state UP, 1 identical error(s) suppressed)
# %6|1769100045.003|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 150127ms in state UP, 1 identical error(s) suppressed)
# %6|1769100045.118|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769100093.068|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50089ms in state UP, 1 identical error(s) suppressed)
# %6|1769100095.255|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50027ms in state UP, 1 identical error(s) suppressed)
# %6|1769100095.255|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50057ms in state UP, 1 identical error(s) suppressed)
# %6|1769100095.304|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50047ms in state UP, 1 identical error(s) suppressed)
# %6|1769100144.217|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769100145.305|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 99965ms in state UP, 1 identical error(s) suppressed)
# %6|1769100145.404|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50034ms in state UP, 1 identical error(s) suppressed)
# %6|1769100194.406|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769100195.527|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 49999ms in state UP, 1 identical error(s) suppressed)
# %6|1769100195.720|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769100195.770|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769100244.599|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769100245.565|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 99774ms in state UP, 1 identical error(s) suppressed)
# %6|1769100245.684|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50035ms in state UP, 1 identical error(s) suppressed)
# %6|1769100295.809|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50000ms in state UP, 1 identical error(s) suppressed)
# %6|1769100296.001|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50040ms in state UP, 1 identical error(s) suppressed)
# %6|1769100296.112|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50040ms in state UP, 1 identical error(s) suppressed)
# %6|1769100342.470|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 97716ms in state UP, 1 identical error(s) suppressed)
# %6|1769100345.851|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 99835ms in state UP, 1 identical error(s) suppressed)
# %6|1769100345.971|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50040ms in state UP, 1 identical error(s) suppressed)
# %6|1769100393.093|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769100396.122|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50036ms in state UP, 1 identical error(s) suppressed)
# %6|1769100396.348|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769100396.407|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769100443.284|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769100446.161|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 99903ms in state UP, 1 identical error(s) suppressed)
# %6|1769100446.286|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769100494.446|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769100496.461|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50044ms in state UP, 1 identical error(s) suppressed)
# %6|1769100544.691|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50103ms in state UP, 1 identical error(s) suppressed)
# %6|1769100546.507|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 99893ms in state UP, 1 identical error(s) suppressed)
# %6|1769100546.614|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50036ms in state UP, 1 identical error(s) suppressed)
# %6|1769100596.766|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50035ms in state UP, 1 identical error(s) suppressed)
# %6|1769100596.787|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769100642.458|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 96697ms in state UP, 1 identical error(s) suppressed)
# %6|1769100646.803|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 99961ms in state UP, 1 identical error(s) suppressed)
# %6|1769100646.917|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50035ms in state UP, 1 identical error(s) suppressed)
# %6|1769100693.122|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769100697.039|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 49996ms in state UP, 1 identical error(s) suppressed)
# %6|1769100697.070|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50036ms in state UP, 1 identical error(s) suppressed)
# %6|1769100743.282|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769100747.195|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769100793.460|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769100797.235|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 100047ms in state UP, 1 identical error(s) suppressed)
# %6|1769100797.354|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769100843.666|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50057ms in state UP, 1 identical error(s) suppressed)
# %6|1769100847.473|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 49999ms in state UP, 1 identical error(s) suppressed)
# %6|1769100847.509|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: connection reset by peer (after 50037ms in state UP)
# %6|1769100897.620|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50035ms in state UP, 1 identical error(s) suppressed)
# %6|1769100942.525|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 97762ms in state UP, 1 identical error(s) suppressed)
# %6|1769100947.657|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 100035ms in state UP)
# %6|1769100947.783|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769100993.150|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769100997.920|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50000ms in state UP, 1 identical error(s) suppressed)
# %6|1769100997.947|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769101043.385|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50069ms in state UP, 1 identical error(s) suppressed)
# %6|1769101048.070|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769101093.664|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50138ms in state UP, 1 identical error(s) suppressed)
# %6|1769101098.112|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 100038ms in state UP, 1 identical error(s) suppressed)
# %6|1769101098.226|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769101144.770|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769101148.551|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50088ms in state UP, 1 identical error(s) suppressed)
# %6|1769101148.551|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50203ms in state UP, 1 identical error(s) suppressed)
# %6|1769101148.551|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50202ms in state UP, 1 identical error(s) suppressed)
# %6|1769101198.714|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769101242.555|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 97631ms in state UP, 1 identical error(s) suppressed)
# %6|1769101248.753|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 100077ms in state UP, 1 identical error(s) suppressed)
# %6|1769101248.876|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769101293.344|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769101299.080|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50081ms in state UP, 1 identical error(s) suppressed)
# %6|1769101299.080|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50087ms in state UP, 1 identical error(s) suppressed)
# %6|1769101343.552|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769101349.155|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 100045ms in state UP, 1 identical error(s) suppressed)
# %6|1769101349.233|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50036ms in state UP, 1 identical error(s) suppressed)
# %6|1769101393.735|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50035ms in state UP, 1 identical error(s) suppressed)
# %6|1769101399.432|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50079ms in state UP, 1 identical error(s) suppressed)
# %6|1769101399.432|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50084ms in state UP, 1 identical error(s) suppressed)
# %6|1769101399.436|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50036ms in state UP, 1 identical error(s) suppressed)
# %6|1769101443.945|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769101449.507|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 100055ms in state UP, 1 identical error(s) suppressed)
# %6|1769101449.609|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50043ms in state UP, 1 identical error(s) suppressed)
# %6|1769101499.784|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50048ms in state UP, 1 identical error(s) suppressed)
# %6|1769101542.471|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 98413ms in state UP, 1 identical error(s) suppressed)
# %6|1769101549.823|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 99255ms in state UP, 1 identical error(s) suppressed)
# %6|1769101549.966|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50042ms in state UP, 1 identical error(s) suppressed)
# %6|1769101593.426|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769101600.124|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769101600.130|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769101643.658|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50078ms in state UP, 1 identical error(s) suppressed)
# %6|1769101650.212|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 100006ms in state UP, 1 identical error(s) suppressed)
# %6|1769101650.280|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50036ms in state UP, 1 identical error(s) suppressed)
# %6|1769101694.860|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50082ms in state UP, 1 identical error(s) suppressed)
# %6|1769101700.594|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50191ms in state UP, 1 identical error(s) suppressed)
# %6|1769101700.595|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50188ms in state UP, 1 identical error(s) suppressed)
# %6|1769101745.978|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769101750.771|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50059ms in state UP, 1 identical error(s) suppressed)
# %6|1769101750.771|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50059ms in state UP, 1 identical error(s) suppressed)
# %6|1769101800.914|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50015ms in state UP, 1 identical error(s) suppressed)
# %6|1769101842.524|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 96372ms in state UP, 1 identical error(s) suppressed)
# %6|1769101850.953|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 100059ms in state UP, 1 identical error(s) suppressed)
# %6|1769101851.079|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769101893.568|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769101901.211|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 49999ms in state UP, 1 identical error(s) suppressed)
# %6|1769101901.245|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769101943.753|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769101951.365|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50036ms in state UP, 1 identical error(s) suppressed)
# %6|1769101993.942|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769102001.403|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 100043ms in state UP, 1 identical error(s) suppressed)
# %6|1769102001.520|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50036ms in state UP, 1 identical error(s) suppressed)
# %6|1769102044.162|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50052ms in state UP, 1 identical error(s) suppressed)
# %6|1769102051.647|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50006ms in state UP, 1 identical error(s) suppressed)
# %6|1769102051.654|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50047ms in state UP, 1 identical error(s) suppressed)
# %6|1769102051.769|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50046ms in state UP, 1 identical error(s) suppressed)
# %6|1769102101.803|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50037ms in state UP, 1 identical error(s) suppressed)
# %6|1769102142.482|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 97193ms in state UP, 1 identical error(s) suppressed)
# %6|1769102151.846|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 150172ms in state UP, 1 identical error(s) suppressed)
# %6|1769102151.951|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50035ms in state UP, 1 identical error(s) suppressed)
# %6|1769102192.685|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50041ms in state UP, 1 identical error(s) suppressed)
# %6|1769102202.066|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50000ms in state UP, 1 identical error(s) suppressed)
# %6|1769102242.843|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50035ms in state UP, 1 identical error(s) suppressed)
# %6|1769102252.104|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 99889ms in state UP, 1 identical error(s) suppressed)
# %6|1769102252.231|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769102293.049|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769102302.352|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 49999ms in state UP, 1 identical error(s) suppressed)
# %6|1769102302.380|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769102343.214|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769102352.506|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769102402.668|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50044ms in state UP, 1 identical error(s) suppressed)
# %6|1769102442.485|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 99151ms in state UP, 1 identical error(s) suppressed)
# %6|1769102452.706|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 150210ms in state UP, 1 identical error(s) suppressed)
# %6|1769102452.828|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769102492.718|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50035ms in state UP, 1 identical error(s) suppressed)
# %6|1769102502.984|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769102502.984|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50038ms in state UP, 1 identical error(s) suppressed)
# %6|1769102542.912|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50042ms in state UP, 1 identical error(s) suppressed)
# %6|1769102553.023|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.18.242:9093/2]: ssl://57.130.18.242:9093/2: Disconnected: SSL connection closed by peer (after 99952ms in state UP, 1 identical error(s) suppressed)
# %6|1769102553.137|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50035ms in state UP, 1 identical error(s) suppressed)
# %6|1769102593.135|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50089ms in state UP, 1 identical error(s) suppressed)
# %6|1769102603.270|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50012ms in state UP, 1 identical error(s) suppressed)
# %6|1769102603.296|FAIL|rdkafka#consumer-16| [thrd:ssl://57.130.19.97:9093/1]: ssl://57.130.19.97:9093/1: Disconnected: SSL connection closed by peer (after 50039ms in state UP, 1 identical error(s) suppressed)
# %6|1769102644.334|FAIL|rdkafka#producer-15| [thrd:ssl://57.130.28.56:9093/0]: ssl://57.130.28.56:9093/0: Disconnected: SSL connection closed by peer (after 50089ms in state UP, 1 identical error(s) suppressed)
# %6|1769102653.423|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50035ms in state UP, 1 identical error(s) suppressed)
# %6|1769102703.593|FAIL|rdkafka#consumer-16| [thrd:GroupCoordinator]: GroupCoordinator: 57.130.19.97:9093: Disconnected: SSL connection closed by peer (after 50036ms in state UP, 1 identical error(s) suppressed)

# %% [markdown]
# ##  Step 2 — Observed weather (yesterday)
# Fetch observed hourly weather, compute time/holiday features, and upsert to `weather_hourly` (v3).

# %%
# --- Weather: fetch + feature engineering ---
weather_df = util.get_yesterday_hourly_weather(
    latitude=LATITUDE,
    longitude=LONGITUDE,
    city=CITY,
)

# Normalize keys (PK: price_area + unix_time)
weather_df["date"] = pd.to_datetime(weather_df["timestamp"], utc=True)
weather_df["unix_time"] = weather_df["date"].astype("int64") // 10**6
weather_df["price_area"] = PRICE_AREA.lower()
weather_df["price_area"] = weather_df["price_area"].astype("string")
weather_df = weather_df.drop(columns=["timestamp", "city"], errors="ignore")

# Calendar features
weather_df["weekday"] = weather_df["date"].dt.weekday.astype("int8")
weather_df["is_weekend"] = weather_df["weekday"].isin([5, 6]).astype("int8")
weather_df["month"] = weather_df["date"].dt.month.astype("int8")
weather_df["season"] = weather_df["month"].map(SEASON_MAP).astype("int8")

# Swedish public holidays
try:
    years = range(weather_df["date"].dt.year.min(), weather_df["date"].dt.year.max() + 1)
    se_holidays = holidays.Sweden(years=years)
    weather_df["is_holiday"] = weather_df["date"].dt.date.isin(se_holidays).astype("int8")
except Exception:
    weather_df["is_holiday"] = 0

cols_out = [
    "unix_time",
    "date",
    "hour",
    "price_area",
    "temperature_2m",
    "apparent_temperature",
    "precipitation",
    "rain",
    "snowfall",
    "cloud_cover",
    "wind_speed_10m",
    "wind_speed_100m",
    "wind_direction_10m",
    "wind_direction_100m",
    "wind_gusts_10m",
    "surface_pressure",
    "weekday",
    "is_weekend",
    "month",
    "season",
    "is_holiday",
]
weather_df = weather_df[cols_out].dropna().reset_index(drop=True)

if len(weather_df):
    print(f"Weather: inserting {len(weather_df)} row(s) for {yesterday}")
    weather_hourly_fg.insert(weather_df, storage="both", wait=True)
else:
    print("Weather: no rows fetched.")
# Out:
# Fetching historical weather for Stockholm (59.3251, 18.0711)...
# Date range: 2026-01-21 to 2026-01-21
# Coordinates: 59.3673095703125°N 18.0°E
# Elevation: 23.0 m asl
# Fetched 24 hourly weather records
# Weather: inserting 24 row(s) for 2026-01-21
# 2026-01-22 17:08:20,812 INFO: 	3 expectation(s) included in expectation_suite.
# Validation succeeded.
# Validation Report saved successfully, explore a summary at https://eu-west.cloud.hopsworks.ai:443/p/127/fs/74/fg/2199
# Uploading Dataframe: 100.00% |██████████| Rows 24/24 | Elapsed Time: 00:00 | Remaining Time: 00:00
# Launching job: weather_hourly_2_offline_fg_materialization
# Job started successfully, you can follow the progress at
# https://eu-west.cloud.hopsworks.ai:443/p/127/jobs/named/weather_hourly_2_offline_fg_materialization/executions
# 2026-01-22 17:08:33,023 INFO: Waiting for execution to finish. Current state: SUBMITTED. Final status: UNDEFINED
# 2026-01-22 17:08:36,381 INFO: Waiting for execution to finish. Current state: RUNNING. Final status: UNDEFINED
# 2026-01-22 17:11:01,615 INFO: Waiting for execution to finish. Current state: SUCCEEDING. Final status: UNDEFINED
# 2026-01-22 17:11:04,970 INFO: Waiting for execution to finish. Current state: FINISHED. Final status: SUCCEEDED
# 2026-01-22 17:11:05,241 INFO: Waiting for log aggregation to finish.
# 2026-01-22 17:11:05,242 INFO: Execution finished successfully.
# Online data ingestion progress: 0.00% |          | Rows 0/24
