# %% [markdown]
# # Notebook 5 – Regular retraining
#
# Purpose:
# - Retrain the model on new data on a regular cadence (e.g., weekly).
# - Compare the new model against the current production model.
# - If the new model is better, promote it (save/overwrite the production version).
# - Log results, metrics, and the decision (kept or replaced production).
#
# Notes:
# - Define training frequency and data window to use.
# - Describe evaluation metrics and thresholds for promotion.
# - Record the latest retraining date and any issues encountered.
