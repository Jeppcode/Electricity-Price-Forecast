# %%
from pathlib import Path
import sys

root_dir = Path("..").resolve()
src_dir = root_dir / "src"
if str(src_dir) not in sys.path:
    sys.path.append(str(src_dir))

from config import ElectricitySettings
settings = ElectricitySettings()

import hopsworks
project = hopsworks.login()
# Out:
# ElectricitySettings initialized
# 2025-12-08 11:29:33,309 INFO: Initializing external client
# 2025-12-08 11:29:33,309 INFO: Base URL: https://c.app.hopsworks.ai:443
# 2025-12-08 11:29:34,656 WARNING: UserWarning: The installed hopsworks client version 4.6.0 may not be compatible with the connected Hopsworks backend version 4.2.2.
# To ensure compatibility please install the latest bug fix release matching the minor version of your backend (4.2) by running 'pip install hopsworks==4.2.*'
# ---------------------------------------------------------------------------
# RestAPIError                              Traceback (most recent call last)
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hopsworks/__init__.py:386, in _prompt_project(valid_connection, project, is_app)
#     385 try:
# --> 386     return valid_connection._project_api._get_project(project)
#     387 except RestAPIError as x:
#
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hopsworks_common/core/project_api.py:104, in ProjectApi._get_project(self, name)
#      99 path_params = [
#     100     "project",
#     101     "getProjectInfo",
#     102     name,
#     103 ]
# --> 104 project_json = _client._send_request("GET", path_params)
#     105 return project.Project.from_response_json(project_json)
#
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hopsworks_common/decorators.py:48, in connected.<locals>.if_connected(inst, *args, **kwargs)
#      47     raise NoHopsworksConnectionError
# ---> 48 return fn(inst, *args, **kwargs)
#
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hopsworks_common/client/base.py:186, in Client._send_request(self, method, path_params, query_params, headers, data, stream, files, with_base_path_params)
#     185 if response.status_code // 100 != 2:
# --> 186     raise exceptions.RestAPIError(url, response)
#     188 if stream:
#
# RestAPIError: Metadata operation error: (url: https://c.app.hopsworks.ai/hopsworks-api/api/project/getProjectInfo/ScalableProject). Server response:
# HTTP code: 401, HTTP reason: Unauthorized, body: b'{"errorCode":320013,"errorMsg":"API key not found in the database"}', error code: 320013, error msg: API key not found in the database, user msg:
#
# The above exception was the direct cause of the following exception:
#
# ProjectException                          Traceback (most recent call last)
# Cell In[1], line 13
#      10 settings = ElectricitySettings()
#      12 import hopsworks
# ---> 13 project = hopsworks.login()
#
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hopsworks/__init__.py:276, in login(host, port, project, api_key_value, api_key_file, hostname_verification, trust_store_path, engine)
#     267 try:
#     268     _hw_connection = _hw_connection(
#     269         host=host,
#     270         port=port,
#    (...)    274         trust_store_path=trust_store_path,
#     275     )
# --> 276     _connected_project = _prompt_project(_hw_connection, project, is_app)
#     277     if _connected_project:
#     278         _set_active_project(_connected_project)
#
# File ~/Documents/KTH/Skalbar_ML/Project/.venv/lib/python3.11/site-packages/hopsworks/__init__.py:388, in _prompt_project(valid_connection, project, is_app)
#     386     return valid_connection._project_api._get_project(project)
#     387 except RestAPIError as x:
# --> 388     raise ProjectException("Could not find project {}".format(project)) from x
#
# ProjectException: Could not find project ScalableProject

# %%
import hopsworks

project = hopsworks.login()  # använder env-vars från settings
fs = project.get_feature_store()
